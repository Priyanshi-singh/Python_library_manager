# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------
# asttokens                     2.2.1
# attrs                         22.2.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# brotlipy                      0.7.0
# certifi                       2022.12.7
# cffi                          1.15.1
# charset-normalizer            2.0.4
# click                         8.1.3
# colorama                      0.4.6
# comtypes                      1.1.14
# conda                         23.1.0
# conda-content-trust           0.1.3
# conda-package-handling        2.0.2
# conda_package_streaming       0.7.0
# contourpy                     1.0.7
# cryptography                  38.0.4
# cycler                        0.11.0
# debugpy                       1.5.1
# decorator                     5.1.1
# distlib                       0.3.6
# dlib                          19.24.0
# executing                     1.2.0
# ...

# %%
conda list
# Out:
# # packages in environment at c:\Users\dell\AppData\Local\miniconda3:
# #
# # Name                    Version                   Build  Channel
# asttokens                 2.2.1              pyhd8ed1ab_0    conda-forge
# attrs                     22.2.0                   pypi_0    pypi
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                pyhd8ed1ab_3    conda-forge
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# brotlipy                  0.7.0           py310h2bbff1b_1002
# bzip2                     1.0.8                he774522_0
# ca-certificates           2022.12.7            h5b45459_0    conda-forge
# certifi                   2022.12.7          pyhd8ed1ab_0    conda-forge
# cffi                      1.15.1          py310h2bbff1b_3
# charset-normalizer        2.0.4              pyhd3eb1b0_0
# click                     8.1.3                    pypi_0    pypi
# ...

# %%
import pip

# %%
installed_lib = pip.get_installed_distributions()
installed_lib_list = sorted(["%s==%s" % (i.key, i.version)
                             for i in installed_lib])
print(installed_lib_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 installed_lib = pip.get_installed_distributions()
#       2 installed_lib_list = sorted(["%s==%s" % (i.key, i.version)
#       3                              for i in installed_lib])
#       4 print(installed_lib_list)
#
# AttributeError: module 'pip' has no attribute 'get_installed_distributions'

# %%
import pkg_resources

dists = [d for d in pkg_resources.working_set]

# %%
dists
# Out:
# [certifi 2022.12.7 (c:\users\dell\appdata\local\miniconda3\lib\site-packages),
#  pytz 2022.7.1 (c:\users\dell\appdata\local\miniconda3\lib\site-packages),
#  pywin32 305.1 (c:\users\dell\appdata\local\miniconda3\lib\site-packages),
#  pypiwin32 223 (c:\users\dell\appdata\local\miniconda3\lib\site-packages),
#  setuptools 65.6.3 (c:\users\dell\appdata\local\miniconda3\lib\site-packages),
#  cryptography 38.0.4 (c:\users\dell\appdata\local\miniconda3\lib\site-packages),
#  pyzmq 23.2.0 (c:\users\dell\appdata\local\miniconda3\lib\site-packages),
#  conda 23.1.0 (c:\users\dell\appdata\local\miniconda3\lib\site-packages),
#  packaging 23.0 (c:\users\dell\appdata\local\miniconda3\lib\site-packages),
#  pip 22.3.1 (c:\users\dell\appdata\local\miniconda3\lib\site-packages),
#  attrs 22.2.0 (c:\users\dell\appdata\local\miniconda3\lib\site-packages),
#  pyOpenSSL 22.0.0 (c:\users\dell\appdata\local\miniconda3\lib\site-packages),
# ...
